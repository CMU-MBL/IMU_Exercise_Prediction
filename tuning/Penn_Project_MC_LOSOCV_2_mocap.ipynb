# %%
# !nvidia-smi
# Out:
# Sun Dec 18 18:20:41 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 516.94       Driver Version: 516.94       CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:09:00.0  On |                  Off |
# |  0%   38C    P8    18W / 450W |    960MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      2676    C+G   ...cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A      7628    C+G   ...dows\System32\WWAHost.exe    N/A      |
# |    0   N/A  N/A      8088    C+G   ...2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A      9356    C+G   C:\Windows\explorer.exe         N/A      |
# |    0   N/A  N/A     10100    C+G   ...artMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A     10420    C+G   ...oot\Office16\POWERPNT.EXE    N/A      |
# |    0   N/A  N/A     11128    C+G   ...e\PhoneExperienceHost.exe    N/A      |
# |    0   N/A  N/A     11328    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     13940    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     14068    C+G   ...ge\Application\msedge.exe    N/A      |
# |    0   N/A  N/A     14864    C+G   ...bbwe\Microsoft.Photos.exe    N/A      |
# |    0   N/A  N/A     16532    C+G   ...462.46\msedgewebview2.exe    N/A      |
# |    0   N/A  N/A     17432    C+G   ...4__8wekyb3d8bbwe\Time.exe    N/A      |
# |    0   N/A  N/A     17664    C+G   ...y\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A     19036    C+G   ...ck\app-4.29.149\slack.exe    N/A      |
# |    0   N/A  N/A     20448    C+G   ...me\Application\chrome.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# #Library

# %% [markdown]
# Access to Google Drive folder

# %%
# import requirements
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Useful library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import random

from tqdm import tqdm

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import LeaveOneOut

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %% [markdown]
# #Constants

# %%
ID_EXERCISE_LABEL       = -2
ID_SUBJECT_LABEL        = -1

NORM_SAMPLE_LENGTH      = 100
# CONSIDERED_SEGMENT      = ['LeftShank', 'RightShank', 'LeftThigh', 'RightThigh', 'Pelvis', 'LeftFoot', 'RightFoot'] # 7 lower limb segments
CONSIDERED_SEGMENT      = ['LeftFoot', 'LeftShank', 'LeftThigh', 'Pelvis', 'RightFoot', 'RightShank', 'RightThigh'] # 7 lower limb segments
NOT_CONSIDERED_INFO     = ['CoMPosition'] # Mocap info: CoMPosition and Orientation
# NOT_CONSIDERED_INFO     = [''] # Mocap info: COMPosition and Orientation
NUM_SEGMENT_INFO        = 1 # only orientation (2 if considering both COM position and orientation)
# NUM_SEGMENT_INFO        = 2 # both COM position and orientation
NUM_AX_PER_SEGMENT_INFO = 3 # x-, y-, and z-

NUM_SUBJECT             = 20 # will remove the 1st subject later due to IMU data

# %%
# --- Model hyper-parameters --- #
# Fixed parameters
LEARNING_RATE = 1e-4
NUM_EPOCHS = 30
ADAM_WEIGHT_DECAY = 1e-2
LEARNING_RATE_REDUCTION_FACTOR = 0.5

num_segment = len(CONSIDERED_SEGMENT) # no. of considered segments for the data
conv_num_in = num_segment*NUM_SEGMENT_INFO*NUM_AX_PER_SEGMENT_INFO # no. of inputs for the model
print('No. of considered segments: ' + str(num_segment))
print('No. of inputs for the model: ' + str(conv_num_in))

# Tuning parameters
BATCH_SIZE_GRID = [16, 32, 64, 128]
CONV_NUM_OUT_GRID = [32, 64, 128, 256]
KERNEL_SIZE_GRID = [4]
STRIDE_GRID = [1]
# POOL_SIZE = [2, 4, 8]
POOL_SIZE = [2]

# Id for tuning parameters
ID_BATCH_SIZE = 0
ID_NUM_OUT = 1
ID_KERNEL_SIZE = 2
ID_STRIDE = 3
ID_POOL_SIZE = 4
# Out:
# No. of considered segments: 7
# No. of inputs for the model: 21

# %%
# Generate the search space
hp_search_space = []

for bs in BATCH_SIZE_GRID:
  for no in CONV_NUM_OUT_GRID:
    for ks in KERNEL_SIZE_GRID:
      for st in STRIDE_GRID:
        for ps in POOL_SIZE:
          temp_point = [bs, no, ks, st, ps]
          hp_search_space.append(temp_point)

print('Size of the search space: ' + str(len(hp_search_space)))
# Out:
# Size of the search space: 16

# %% [markdown]
# #Utils

# %% [markdown]
# **Pre-processing**

# %%
# all helper function here
# helper functions
def mkfolder(pth):
  if not os.path.exists(pth):
    os.mkdir(pth)

def read(pth):
  return pd.read_csv(pth)

# Load and re-format the data file
def load_df(pth):
  dtframe   = read(pth)
  dtframe = dtframe.iloc[:, 1:] # remove the first column

  # Re-formatting the column's names
  # e.g., Pevist COMPosition X, LeftFoot Orientation Z, etc.
  names     = list(dtframe.columns)
  names     = [name.split('.')[0] for name in names]
  names_2   = dtframe.iloc[0, :]
  names_3   = dtframe.iloc[1, :]

  for i in range(len(names)):
    names[i] = names[i] + ' ' + names_2[i] + ' ' + names_3[i]

  dtframe         = dtframe.iloc[2:, :] # remove the first 2 rows
  dtframe.columns = names # update new column's names

  return dtframe

def slice_df(dtframe):
  cols = sorted(dtframe.columns)

  req_cols = [col for col in cols if col.split(' ')[0] in CONSIDERED_SEGMENT] # only keep data from considered segments
  req_cols = [col for col in req_cols if col.split(' ')[1] not in NOT_CONSIDERED_INFO] # not use information from COM position

  dtframe = dtframe.loc[:, req_cols]

  return dtframe

# One hot encoding
def one_hot_encoding(label, num_exercise):
  temp        = np.zeros(num_exercise)
  temp[label] = 1

  return temp

# One hot decoding
def one_hot_decoding(num):
  if num.shape[0] > 0:
    temp = np.array([np.where(row == 1) for row in num])
  else:
    temp = np.argwhere(num == 1)

  return temp

# Wrapping angles
def wrapping_angle(arr, info):
  new_arr = np.zeros((arr.shape[0], arr.shape[-1]))
  for i in range(arr.shape[-1]):
    if i in info.keys():
      angle = info[i]
      for j in range(arr.shape[0]):
        new_arr[j, i] = arr[j, i] % angle 
    else:
      new_arr[:, i] = arr[:, i]
  
  return new_arr

# Normalize data to have the same sample length for training the network
def normLength(arr, maxlength):
  new_arr = np.zeros((maxlength, arr.shape[-1]))
  for i in range(arr.shape[-1]):
    a = arr[:, i]
    k = a.shape[0]
    y = np.interp(np.linspace(0, 1, maxlength), np.linspace(0, 1, k), a)
    new_arr[:, i] = y
  return new_arr

# %% [markdown]
# **Dataset handler**

# %%
class MyDataset(Dataset):
    def __init__(self, list_of_samples, to_size):
      self.to_size = to_size

      list_of_samples = [normLength(sample, NORM_SAMPLE_LENGTH).T for sample in list_of_samples]

      self.X = [sample[:ID_EXERCISE_LABEL, :] for sample in list_of_samples]
      
      self.Y = [one_hot_encoding(int(sample[ID_EXERCISE_LABEL, :][0]), num_exercise) for sample in list_of_samples]

    def __len__(self):
      return len(self.Y)

    def __getitem__(self, idx):
      x = torch.from_numpy(self.X[idx]).float()
      y = self.Y[idx]
      # y = int(self.Y[0])
      # y = np.array(y)
      if device == 'cuda':
        x = x.to(device)
        y = torch.from_numpy(y)
        y = y.to(device)
      return x, y

# %% [markdown]
# **Model**

# %% [markdown]
# Architecture

# %%
class CNN_Alter_Block(nn.Module):
    def __init__(self, num_in, num_out, kernel_size, stride, pool_size):
        super(CNN_Alter_Block, self).__init__()
        self.conv1    = nn.Conv1d(num_in, num_out, kernel_size, stride)      # input paramters
        self.relu1    = nn.ReLU()
        self.bnorm    = nn.BatchNorm1d(num_out)
        self.pooling  = nn.MaxPool1d((pool_size))

        self.flatten  = nn.Flatten()
        self.dropout  = nn.Dropout(p = 0.5)
        self.fcl      = nn.LazyLinear(out_features = 37)
        self.sfmx     = nn.Softmax(dim=1)

    def forward(self, x):
        # x = x.cuda()
        x = self.conv1(x)
        x = self.relu1(x)
        x = self.bnorm(x)
        x = self.pooling(x)

        x = self.flatten(x)
        x = self.dropout(x)
        x = self.fcl(x)
        x = self.sfmx(x)
        return x

# %% [markdown]
# Evaluate prediction

# %%
# ---> Remember to check one more time before running the loop
def predict(some_tensor, labs):
  some_tensor = some_tensor.cpu().detach().numpy()
  labs        = labs.cpu().detach().numpy()

  count = 0

  for i in range(some_tensor.shape[0]):
    temp_pred = np.argmax(some_tensor[i])
    temp_truth = np.argmax(labs[i])

    # print('Prediction = ' + str(temp_pred) + ' - ' + 'Truth = ' + str(temp_truth))

    if temp_pred == temp_truth:
      count = count + 1
    else:
      pass # do nothing
  
  return count

# %% [markdown]
# Model loop

# %%
val_acc, best_val_loss = 0, 1.0
def train_loop(dataloader, model, loss_fn, optimizer):
    global train_mode
    train_mode = True

    size        = len(dataloader.dataset)
    num_batches = len(dataloader)
    train_loss, correct, sched_factor = 0, 0, 0
    for batch, (X, y) in enumerate(dataloader):
        # print(X)
        # Compute prediction and loss
        pred = model(X)
        # print(pred)
        # print(predict(pred, y))
        # print('----------------------')
        # print(pred)
        # print(y)
        # break
        y = y.type(torch.FloatTensor)
        if device == 'cuda': y = y.cuda()

        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 20 == 0:
            loss, current = loss.item(), batch * len(X)
            # print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
        
        correct     += predict(pred, y)
        train_loss  += loss_fn(pred, y).item()

    train_loss /= num_batches
    train_losses.append(train_loss)
    correct /= size

    scheduler.step(train_loss)

    # print(f"Train Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {train_loss:>8f} \n")

    return correct

def val_loop(dataloader, model, loss_fn):
    global val_acc, train_mode, best_val_loss
    train_mode = False

    size        = len(dataloader.dataset)
    num_batches = len(dataloader)
    val_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            # pred = predict(pred, y)
            y = y.type(torch.FloatTensor)
            if device == 'cuda': y = y.cuda()
            val_loss += loss_fn(pred, y).item()
            # correct += (pred.argmax(1) == y).type(torch.float).sum().item() # comment out
            correct += predict(pred, y)


    val_loss /= num_batches
    val_losses.append(val_loss)
    correct /= size
    print(f"Val Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {val_loss:>8f} \n")

    model_name = 'MaxJump5050_lstm_fcn_all_32_1en4_sch_801010_wd.pt'
    if correct > val_acc:
      torch.save(model, model_name)
      val_acc = correct
      best_val_loss = val_loss
      print('Model saved\n')
    elif correct == val_acc and val_loss < best_val_loss:
      torch.save(model, model_name)
      best_val_loss = val_loss
      print('Model saved\n')

def test_loop(dataloader, model, loss_fn):
    global train_mode
    train_mode = False

    size        = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct, size = 0, 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            # pred = predict(pred, y)
            y = y.type(torch.FloatTensor)
            if device == 'cuda': y = y.cuda()
            test_loss += loss_fn(pred, y).item()
            # correct += (pred.argmax(1) == y).type(torch.float).sum().item() # comment out
            correct += predict(pred, y)
            size    += y.shape[0]

    test_loss /= num_batches
    correct /= size
    # print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

    return correct

# %% [markdown]
# LOOSCV

# %%
def losocv_split_train_list(all_subject_id, test_subject):  
  train_list = [m for m in all_subject_id if m != test_subject]

  return train_list

# %% [markdown]
# #Subjects and Exercises

# %%
# THIS IS WHEN USING COLAB GPU <------------------- NOTICE
root_path = 'drive/MyDrive/mbl/parsed_h5_csv/'
subs = sorted(list(os.listdir(root_path)))
subs = subs[:-1] # remove 'merged' # we don't have 'merged' in this folder

# %%
# THIS IS WHEN USING LOCAL MACHINE <------------------- NOTICE
root_path = 'OneDrive/Documents/parsed_MoCap_kinematics/'
subs = sorted(list(os.listdir(root_path)))
# subs = subs[:-1] # remove 'merged' # we don't have 'merged' in this folder

# %%
# total should be 20
num_subject = len(subs)
num_subject
# Out:
# 20

# %% [markdown]
# Obtain exercises

# %%
exercises = [sorted(os.listdir(root_path+sub)) for sub in subs]

# Get types of exercises (i.e., physical activities)
exercise_types = []
for ex in exercises:
  exercise_types.extend(ex)

# %%
for ex in exercises:
  print(len(ex), ex)
# Out:
# 14 ['CMJDL', 'DropJumpDL', 'DropLandDL', 'HeelRaise', 'Lunge', 'MaxJump', 'Run', 'SqDL', 'SqHalfDL', 'StepDnH', 'StepDnL', 'StepUpH', 'StepUpL', 'Walk']
# 37 ['BulgSq', 'CMJDL', 'CMJSL', 'DeclineSq', 'DropJumpDL', 'DropJumpSL', 'DropLandDL', 'DropLandSL', 'FwHop', 'FwHopFast', 'FwJump', 'FwJumpFast', 'HeelRaise', 'LatHop', 'LatHopFast', 'LatJump', 'LatJumpFast', 'Lunge', 'MaxHop', 'MaxJump', 'Pose', 'Run', 'RunCut', 'RunDec', 'SpainSq', 'SplitJump', 'SportJump', 'SqDL', 'SqHalfDL', 'SqHalfSL', 'SqSL', 'StepDnH', 'StepDnL', 'StepUpH', 'StepUpL', 'SumoSq', 'Walk']
# 37 ['BulgSq', 'CMJDL', 'CMJSL', 'DeclineSq', 'DropJumpDL', 'DropJumpSL', 'DropLandDL', 'DropLandSL', 'FwHop', 'FwHopFast', 'FwJump', 'FwJumpFast', 'HeelRaise', 'LatHop', 'LatHopFast', 'LatJump', 'LatJumpFast', 'Lunge', 'MaxHop', 'MaxJump', 'Pose', 'Run', 'RunCut', 'RunDec', 'SpainSq', 'SplitJump', 'SportJump', 'SqDL', 'SqHalfDL', 'SqHalfSL', 'SqSL', 'StepDnH', 'StepDnL', 'StepUpH', 'StepUpL', 'SumoSq', 'Walk']
# 37 ['BulgSq', 'CMJDL', 'CMJSL', 'DeclineSq', 'DropJumpDL', 'DropJumpSL', 'DropLandDL', 'DropLandSL', 'FwHop', 'FwHopFast', 'FwJump', 'FwJumpFast', 'HeelRaise', 'LatHop', 'LatHopFast', 'LatJump', 'LatJumpFast', 'Lunge', 'MaxHop', 'MaxJump', 'Pose', 'Run', 'RunCut', 'RunDec', 'SpainSq', 'SplitJump', 'SportJump', 'SqDL', 'SqHalfDL', 'SqHalfSL', 'SqSL', 'StepDnH', 'StepDnL', 'StepUpH', 'StepUpL', 'SumoSq', 'Walk']
# 37 ['BulgSq', 'CMJDL', 'CMJSL', 'DeclineSq', 'DropJumpDL', 'DropJumpSL', 'DropLandDL', 'DropLandSL', 'FwHop', 'FwHopFast', 'FwJump', 'FwJumpFast', 'HeelRaise', 'LatHop', 'LatHopFast', 'LatJump', 'LatJumpFast', 'Lunge', 'MaxHop', 'MaxJump', 'Pose', 'Run', 'RunCut', 'RunDec', 'SpainSq', 'SplitJump', 'SportJump', 'SqDL', 'SqHalfDL', 'SqHalfSL', 'SqSL', 'StepDnH', 'StepDnL', 'StepUpH', 'StepUpL', 'SumoSq', 'Walk']
# 37 ['BulgSq', 'CMJDL', 'CMJSL', 'DeclineSq', 'DropJumpDL', 'DropJumpSL', 'DropLandDL', 'DropLandSL', 'FwHop', 'FwHopFast', 'FwJump', 'FwJumpFast', 'HeelRaise', 'LatHop', 'LatHopFast', 'LatJump', 'LatJumpFast', 'Lunge', 'MaxHop', 'MaxJump', 'Pose', 'Run', 'RunCut', 'RunDec', 'SpainSq', 'SplitJump', 'SportJump', 'SqDL', 'SqHalfDL', 'SqHalfSL', 'SqSL', 'StepDnH', 'StepDnL', 'StepUpH', 'StepUpL', 'SumoSq', 'Walk']
# 37 ['BulgSq', 'CMJDL', 'CMJSL', 'DeclineSq', 'DropJumpDL', 'DropJumpSL', 'DropLandDL', 'DropLandSL', 'FwHop', 'FwHopFast', 'FwJump', 'FwJumpFast', 'HeelRaise', 'LatHop', 'LatHopFast', 'LatJump', 'LatJumpFast', 'Lunge', 'MaxHop', 'MaxJump', 'Pose', 'Run', 'RunCut', 'RunDec', 'SpainSq', 'SplitJump', 'SportJump', 'SqDL', 'SqHalfDL', 'SqHalfSL', 'SqSL', 'StepDnH', 'StepDnL', 'StepUpH', 'StepUpL', 'SumoSq', 'Walk']
# 37 ['BulgSq', 'CMJDL', 'CMJSL', 'DeclineSq', 'DropJumpDL', 'DropJumpSL', 'DropLandDL', 'DropLandSL', 'FwHop', 'FwHopFast', 'FwJump', 'FwJumpFast', 'HeelRaise', 'LatHop', 'LatHopFast', 'LatJump', 'LatJumpFast', 'Lunge', 'MaxHop', 'MaxJump', 'Pose', 'Run', 'RunCut', 'RunDec', 'SpainSq', 'SplitJump', 'SportJump', 'SqDL', 'SqHalfDL', 'SqHalfSL', 'SqSL', 'StepDnH', 'StepDnL', 'StepUpH', 'StepUpL', 'SumoSq', 'Walk']
# 36 ['BulgSq', 'CMJDL', 'CMJSL', 'DeclineSq', 'DropJumpDL', 'DropJumpSL', 'DropLandDL', 'DropLandSL', 'FwHop', 'FwHopFast', 'FwJump', 'HeelRaise', 'LatHop', 'LatHopFast', 'LatJump', 'LatJumpFast', 'Lunge', 'MaxHop', 'MaxJump', 'Pose', 'Run', 'RunCut', 'RunDec', 'SpainSq', 'SplitJump', 'SportJump', 'SqDL', 'SqHalfDL', 'SqHalfSL', 'SqSL', 'StepDnH', 'StepDnL', 'StepUpH', 'StepUpL', 'SumoSq', 'Walk']
# 36 ['BulgSq', 'CMJDL', 'CMJSL', 'DeclineSq', 'DropJumpDL', 'DropJumpSL', 'DropLandDL', 'DropLandSL', 'FwHop', 'FwHopFast', 'FwJump', 'FwJumpFast', 'HeelRaise', 'LatHop', 'LatHopFast', 'LatJump', 'LatJumpFast', 'Lunge', 'MaxHop', 'MaxJump', 'Pose', 'Run', 'RunCut', 'RunDec', 'SplitJump', 'SportJump', 'SqDL', 'SqHalfDL', 'SqHalfSL', 'SqSL', 'StepDnH', 'StepDnL', 'StepUpH', 'StepUpL', 'SumoSq', 'Walk']
# 34 ['BulgSq', 'CMJDL', 'CMJSL', 'DeclineSq', 'DropJumpSL', 'DropLandDL', 'DropLandSL', 'FwHop', 'FwHopFast', 'FwJump', 'FwJumpFast', 'HeelRaise', 'LatHop', 'LatHopFast', 'LatJump', 'LatJumpFast', 'Lunge', 'MaxHop', 'MaxJump', 'Run', 'RunCut', 'RunDec', 'SpainSq', 'SplitJump', 'SportJump', 'SqDL', 'SqHalfDL', 'SqHalfSL', 'SqSL', 'StepDnL', 'StepUpH', 'StepUpL', 'SumoSq', 'Walk']
# 37 ['BulgSq', 'CMJDL', 'CMJSL', 'DeclineSq', 'DropJumpDL', 'DropJumpSL', 'DropLandDL', 'DropLandSL', 'FwHop', 'FwHopFast', 'FwJump', 'FwJumpFast', 'HeelRaise', 'LatHop', 'LatHopFast', 'LatJump', 'LatJumpFast', 'Lunge', 'MaxHop', 'MaxJump', 'Pose', 'Run', 'RunCut', 'RunDec', 'SpainSq', 'SplitJump', 'SportJump', 'SqDL', 'SqHalfDL', 'SqHalfSL', 'SqSL', 'StepDnH', 'StepDnL', 'StepUpH', 'StepUpL', 'SumoSq', 'Walk']
# 36 ['BulgSq', 'CMJDL', 'CMJSL', 'DeclineSq', 'DropJumpDL', 'DropJumpSL', 'DropLandDL', 'DropLandSL', 'FwHop', 'FwHopFast', 'FwJump', 'FwJumpFast', 'HeelRaise', 'LatHop', 'LatHopFast', 'LatJump', 'Lunge', 'MaxHop', 'MaxJump', 'Pose', 'Run', 'RunCut', 'RunDec', 'SpainSq', 'SplitJump', 'SportJump', 'SqDL', 'SqHalfDL', 'SqHalfSL', 'SqSL', 'StepDnH', 'StepDnL', 'StepUpH', 'StepUpL', 'SumoSq', 'Walk']
# 36 ['BulgSq', 'CMJDL', 'CMJSL', 'DeclineSq', 'DropJumpDL', 'DropJumpSL', 'DropLandDL', 'DropLandSL', 'FwHop', 'FwHopFast', 'FwJump', 'FwJumpFast', 'HeelRaise', 'LatHop', 'LatHopFast', 'LatJump', 'LatJumpFast', 'Lunge', 'MaxHop', 'MaxJump', 'Pose', 'Run', 'RunCut', 'RunDec', 'SpainSq', 'SplitJump', 'SportJump', 'SqDL', 'SqHalfDL', 'SqHalfSL', 'SqSL', 'StepDnH', 'StepUpH', 'StepUpL', 'SumoSq', 'Walk']
# 36 ['BulgSq', 'CMJDL', 'CMJSL', 'DeclineSq', 'DropJumpDL', 'DropJumpSL', 'DropLandDL', 'DropLandSL', 'FwHop', 'FwHopFast', 'FwJump', 'FwJumpFast', 'HeelRaise', 'LatHop', 'LatHopFast', 'LatJump', 'LatJumpFast', 'Lunge', 'MaxHop', 'MaxJump', 'Pose', 'Run', 'RunCut', 'RunDec', 'SpainSq', 'SplitJump', 'SportJump', 'SqDL', 'SqHalfDL', 'SqHalfSL', 'SqSL', 'StepDnL', 'StepUpH', 'StepUpL', 'SumoSq', 'Walk']
# 37 ['BulgSq', 'CMJDL', 'CMJSL', 'DeclineSq', 'DropJumpDL', 'DropJumpSL', 'DropLandDL', 'DropLandSL', 'FwHop', 'FwHopFast', 'FwJump', 'FwJumpFast', 'HeelRaise', 'LatHop', 'LatHopFast', 'LatJump', 'LatJumpFast', 'Lunge', 'MaxHop', 'MaxJump', 'Pose', 'Run', 'RunCut', 'RunDec', 'SpainSq', 'SplitJump', 'SportJump', 'SqDL', 'SqHalfDL', 'SqHalfSL', 'SqSL', 'StepDnH', 'StepDnL', 'StepUpH', 'StepUpL', 'SumoSq', 'Walk']
# 37 ['BulgSq', 'CMJDL', 'CMJSL', 'DeclineSq', 'DropJumpDL', 'DropJumpSL', 'DropLandDL', 'DropLandSL', 'FwHop', 'FwHopFast', 'FwJump', 'FwJumpFast', 'HeelRaise', 'LatHop', 'LatHopFast', 'LatJump', 'LatJumpFast', 'Lunge', 'MaxHop', 'MaxJump', 'Pose', 'Run', 'RunCut', 'RunDec', 'SpainSq', 'SplitJump', 'SportJump', 'SqDL', 'SqHalfDL', 'SqHalfSL', 'SqSL', 'StepDnH', 'StepDnL', 'StepUpH', 'StepUpL', 'SumoSq', 'Walk']
# 37 ['BulgSq', 'CMJDL', 'CMJSL', 'DeclineSq', 'DropJumpDL', 'DropJumpSL', 'DropLandDL', 'DropLandSL', 'FwHop', 'FwHopFast', 'FwJump', 'FwJumpFast', 'HeelRaise', 'LatHop', 'LatHopFast', 'LatJump', 'LatJumpFast', 'Lunge', 'MaxHop', 'MaxJump', 'Pose', 'Run', 'RunCut', 'RunDec', 'SpainSq', 'SplitJump', 'SportJump', 'SqDL', 'SqHalfDL', 'SqHalfSL', 'SqSL', 'StepDnH', 'StepDnL', 'StepUpH', 'StepUpL', 'SumoSq', 'Walk']
# 37 ['BulgSq', 'CMJDL', 'CMJSL', 'DeclineSq', 'DropJumpDL', 'DropJumpSL', 'DropLandDL', 'DropLandSL', 'FwHop', 'FwHopFast', 'FwJump', 'FwJumpFast', 'HeelRaise', 'LatHop', 'LatHopFast', 'LatJump', 'LatJumpFast', 'Lunge', 'MaxHop', 'MaxJump', 'Pose', 'Run', 'RunCut', 'RunDec', 'SpainSq', 'SplitJump', 'SportJump', 'SqDL', 'SqHalfDL', 'SqHalfSL', 'SqSL', 'StepDnH', 'StepDnL', 'StepUpH', 'StepUpL', 'SumoSq', 'Walk']
# 37 ['BulgSq', 'CMJDL', 'CMJSL', 'DeclineSq', 'DropJumpDL', 'DropJumpSL', 'DropLandDL', 'DropLandSL', 'FwHop', 'FwHopFast', 'FwJump', 'FwJumpFast', 'HeelRaise', 'LatHop', 'LatHopFast', 'LatJump', 'LatJumpFast', 'Lunge', 'MaxHop', 'MaxJump', 'Pose', 'Run', 'RunCut', 'RunDec', 'SpainSq', 'SplitJump', 'SportJump', 'SqDL', 'SqHalfDL', 'SqHalfSL', 'SqSL', 'StepDnH', 'StepDnL', 'StepUpH', 'StepUpL', 'SumoSq', 'Walk']

# %%
exercise_types = np.array(exercise_types)
exercise_types, _ = np.unique(exercise_types, return_index=True)
exercise_types = exercise_types.tolist()
exercise_types
# Out:
# ['BulgSq',
#  'CMJDL',
#  'CMJSL',
#  'DeclineSq',
#  'DropJumpDL',
#  'DropJumpSL',
#  'DropLandDL',
#  'DropLandSL',
#  'FwHop',
#  'FwHopFast',
#  'FwJump',
#  'FwJumpFast',
#  'HeelRaise',
#  'LatHop',
#  'LatHopFast',
#  'LatJump',
#  'LatJumpFast',
#  'Lunge',
#  'MaxHop',
#  'MaxJump',
#  'Pose',
#  'Run',
#  'RunCut',
#  'RunDec',
#  'SpainSq',
#  'SplitJump',
#  'SportJump',
#  'SqDL',
#  'SqHalfDL',
#  'SqHalfSL',
#  'SqSL',
#  'StepDnH',
#  'StepDnL',
#  'StepUpH',
#  'StepUpL',
#  'SumoSq',
#  'Walk']

# %%
# total should be 37
num_exercise = len(exercise_types)
num_exercise
# Out:
# 37

# %% [markdown]
# Label exercises

# %%
exercise_code = list(range(0, num_exercise))
label_code = dict(zip(exercise_types, exercise_code))
code_label = dict(zip(exercise_code, exercise_types))

# %% [markdown]
# Label subjects

# %%
subs_code = list(range(0, num_subject))
subject_code = dict(zip(subs, subs_code))
code_subject = dict(zip(subs_code, subs))

# %% [markdown]
# #Collect data samples

# %%
sample_list, file_paths = [], []

# The number below depends on how many sensor information we'd like to use
# e.g., if we use 4 sensors: left and right thigh and shank, and 2 information:
# accelerometer (3 axes) and gyroscope (3 axes), we would have 4*(3+3) = 24, 
# since we have the last column for target --> 25 columns in total

# See parts_to_consider in the slice_df function to define this number
# not_25 = 0
# not_31 = 0
# not_37 = 0
# not_43 = 0
# not_49 = 0
# not_55 = 0
# not_61 = 0

# not_62 = 0 # 62 since we now added 1 more column at the end for subject ID


num_missing_dt = 0 # count number of files with missing data to remove them out
num_col_in_dt = num_segment*NUM_SEGMENT_INFO*NUM_AX_PER_SEGMENT_INFO + 2 # adding exercise + subject labels

print("Number of columns that should be in the dataframe = " + str(num_col_in_dt))

no_of_samples = None

# Loop through subjects
for subject in tqdm(subs[1:]): 
  print()
  print('Collecting data from subject ' + str(subject) + ' ...')

  for ex in exercise_types:
    # If the subject perform the task
    try:
      folder_path = root_path + subject + '/' + ex + '/'
      file_names = os.listdir(folder_path) # obtain all parsed data files
      no_of_samples = len(file_names) # to display the no. of samples lately

      for file_name in file_names:
        sample_path = folder_path + file_name        
        df = load_df(sample_path) # load and re-format the data file
        df = slice_df(df) # pick data from considered sensors and remove unnecessary information
        df['target'] = label_code[ex] # add output for the data file
        df['subject_id'] = subject_code[subject] # add subject id for the data

        sample_arr = np.array(df).astype(float) # convert to numpy array type

        # print(sample_arr.shape[1])

        # Check if the data has all considered parts
        if sample_arr.shape[1] != num_col_in_dt:
          num_missing_dt += 1
        else:
          sample_list.append(sample_arr)

        # break
      # print('\n' + str(no_of_samples) + ' samples collected from ' + ex)
      
    except:
      # print('\n' + ex + ' was missing')
      pass # do nothing

  print() # TBD
# Out:
# Number of columns that should be in the dataframe = 23
#   0%|                                                                                           | 0/19 [00:00<?, ?it/s]
# Collecting data from subject SUB02 ...
#   5%|████▎                                                                              | 1/19 [00:00<00:11,  1.63it/s]
# Collecting data from subject SUB03 ...
#  11%|████████▋                                                                          | 2/19 [00:01<00:10,  1.56it/s]
# Collecting data from subject SUB04 ...
#  16%|█████████████                                                                      | 3/19 [00:01<00:10,  1.56it/s]
# Collecting data from subject SUB05 ...
#  21%|█████████████████▍                                                                 | 4/19 [00:02<00:09,  1.58it/s]
# Collecting data from subject SUB06 ...
#  26%|█████████████████████▊                                                             | 5/19 [00:03<00:08,  1.57it/s]
# Collecting data from subject SUB07 ...
#  32%|██████████████████████████▏                                                        | 6/19 [00:03<00:08,  1.55it/s]
# Collecting data from subject SUB08 ...
#  37%|██████████████████████████████▌                                                    | 7/19 [00:04<00:07,  1.53it/s]
# Collecting data from subject SUB09 ...
#  42%|██████████████████████████████████▉                                                | 8/19 [00:05<00:07,  1.55it/s]
# Collecting data from subject SUB10 ...
#  47%|███████████████████████████████████████▎                                           | 9/19 [00:05<00:06,  1.57it/s]
# Collecting data from subject SUB11 ...
#  53%|███████████████████████████████████████████▏                                      | 10/19 [00:06<00:05,  1.58it/s]
# Collecting data from subject SUB12 ...
#  58%|███████████████████████████████████████████████▍                                  | 11/19 [00:07<00:05,  1.59it/s]
# Collecting data from subject SUB14 ...
#  63%|███████████████████████████████████████████████████▊                              | 12/19 [00:07<00:04,  1.60it/s]
# Collecting data from subject SUB15 ...
#  68%|████████████████████████████████████████████████████████                          | 13/19 [00:08<00:03,  1.60it/s]
# Collecting data from subject SUB16 ...
#  74%|████████████████████████████████████████████████████████████▍                     | 14/19 [00:08<00:03,  1.61it/s]
# Collecting data from subject SUB17 ...
#  79%|████████████████████████████████████████████████████████████████▋                 | 15/19 [00:09<00:02,  1.56it/s]
# Collecting data from subject SUB18 ...
#  84%|█████████████████████████████████████████████████████████████████████             | 16/19 [00:10<00:02,  1.48it/s]
# Collecting data from subject SUB19 ...
#  89%|█████████████████████████████████████████████████████████████████████████▎        | 17/19 [00:10<00:01,  1.49it/s]
# Collecting data from subject SUB21 ...
#  95%|█████████████████████████████████████████████████████████████████████████████▋    | 18/19 [00:11<00:00,  1.49it/s]
# Collecting data from subject SUB22 ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 19/19 [00:12<00:00,  1.55it/s]

# %%
len(sample_list)
# Out:
# 3211

# %%
sample_list[0].shape
# Out:
# (197, 23)

# %%
num_col_in_dt
# Out:
# 23

# %% [markdown]
# #Clustering analysis

# %% [markdown]
# Wrapping samples

# %%
wrapping_sample_list = []

# info = {3: -360, 5: -360} # test for BulgSq
info = {3: -360}

for t_sample in tqdm(sample_list):
  t_wrapping_sample = wrapping_angle(t_sample, info)
  wrapping_sample_list.append(t_wrapping_sample)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 3211/3211 [00:00<00:00, 20845.19it/s]

# %% [markdown]
# Normalize samples

# %%
norm_sample_list = []

# for t_sample in tqdm(sample_list):
for t_sample in tqdm(wrapping_sample_list):
  t_norm_sample = normLength(t_sample, NORM_SAMPLE_LENGTH)
  norm_sample_list.append(t_norm_sample)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 3211/3211 [00:02<00:00, 1405.31it/s]

# %%
# Get the label (i.e., exercise type of a sample)
print(len(norm_sample_list))
print(norm_sample_list[300][0, -1])
print(norm_sample_list[300].shape)
# Out:
# 3211
# 2.0
# (100, 23)

# %% [markdown]
# Frame data

# %%
dt_frame = []
ex_label = []
num_samples = len(norm_sample_list)

for i in range(num_samples):
  dt_frame.append(norm_sample_list[i][:, 0:60].flatten('F'))
  ex_label.append(norm_sample_list[i][0, -2])

dt_frame = np.array(dt_frame)
ex_label = np.array(ex_label)

# %%
dt_frame.shape
# Out:
# (3211, 2300)

# %%
ex_label.shape
# Out:
# (3211,)

# %%
ex_label
# Out:
# array([ 0.,  0.,  0., ..., 36., 36., 36.])

# %%
# visualize a specific task
fig, ax = plt.subplots(figsize=(7,5), dpi=100)
selected_exercise = exercise_types[3]
temp_no_samples = 0

ex_all_reps_line = []
for i in range(num_samples):
  if ex_label[i] == label_code[selected_exercise]:
    ax.plot(dt_frame[i, :], linewidth = 0.4, color = '0.8')
    ex_all_reps_line.append(dt_frame[i, :])
    temp_no_samples += 1

# ax.set_xlim([0, 2300])
ax.set_xlabel('Time Step')
ax.set_ylabel('Undefined Unit')
ax.set_title(selected_exercise + ' Exercise')

ex_all_reps_line = np.array(ex_all_reps_line)
ex_avg_line = np.mean(ex_all_reps_line, axis = 0)
ax.plot(ex_avg_line, 'r--', linewidth = 1.2)
# ax.set_ylim([-65, 65])

# The average line only
fig1, ax1 = plt.subplots(figsize=(7,5), dpi=100)
ax1.plot(ex_avg_line, 'r-', linewidth = 1.2)

# ax1.set_xlim([0, 2300])
ax1.set_xlabel('Time Step')
ax1.set_ylabel('Undefined Unit')
ax1.set_title(selected_exercise + ' Exercise')
# ax1.set_ylim([-65, 65])

plt.show()
print(temp_no_samples)

# %%
# --- Plot --- #
# visualize a specific task
fig, ax = plt.subplots(figsize=(20,3), dpi=100)
# fig, ax = plt.subplots(figsize=(7,5), dpi=100)

selected_exercise = exercise_types[2]
temp_no_samples = 0

ex_all_reps_line = []
for i in range(num_samples):
  if ex_label[i] == label_code[selected_exercise]:
    ax.plot(dt_frame[i, :], linewidth = 0.4, color = '0.8')
    ex_all_reps_line.append(dt_frame[i, :])
    temp_no_samples += 1

# ax.set_xlim([0, 2300])
ax.set_xlabel('Time Step')
ax.set_ylabel('Angle (degree)')
ax.set_title(selected_exercise + ' Exercise')

ex_all_reps_line = np.array(ex_all_reps_line)
ex_avg_line = np.mean(ex_all_reps_line, axis = 0)
ax.plot(ex_avg_line, 'r--', linewidth = 1.2)
ax.set_xlim([0, 2100])
# ax.set_ylim([-300, 300])
ax.set_ylim([-400, 400])
# ax.set_ylim([-180, 180])


# Segment different sensor positions
segment_list = sorted(CONSIDERED_SEGMENT)
for i in range(len(segment_list)):
  ax.axvline(i*300, linewidth = 0.8, color = 'b')
  # ax.annotate(CONSIDERED_IMU_POSITION[i], (i*600 + 300, -1.5*bound), ha = 'center', bbox = dict(boxstyle ="round", fc ="0.95", ec = '0.8'))
  ax.annotate(segment_list[i], (i*300 + 150, -250), ha = 'center', bbox = dict(boxstyle ="round", fc ="0.95", ec = '0.8'))

# Segment different sensor type (i.e., accelerometer and gyroscope)
ga_label = ['x-', 'y-', 'z-']
for i in range(conv_num_in):
  ax.axvline(i*100, linewidth = 0.1, color = 'b')
  # ax.annotate(ga_label[int(i % len(ga_label))], (i*100 + 50, 1.5*bound), ha = 'center')
  ax.annotate(ga_label[int(i % len(ga_label))], (i*100 + 50, 250), ha = 'center')

# # The average line only
# fig1, ax1 = plt.subplots(figsize=(7,5), dpi=100)
# ax1.plot(ex_avg_line, 'r-', linewidth = 1.2)

# ax1.set_xlim([0, 6000])
# ax1.set_xlabel('Time Step')
# ax1.set_ylabel('Undefined Unit')
# ax1.set_title(selected_exercise + ' Exercise')
# # ax1.set_ylim([-65, 65])

plt.show()
print(temp_no_samples)
# Out:
# 64

# %%
np.argwhere(np.isnan(ex_all_reps_line))
# Out:
# array([], shape=(0, 2), dtype=int64)

# %% [markdown]
# Form the averaged data frame

# %%
avg_dt_frame = []

for ex in range(num_exercise):
  
  temp_all_reps = []

  for i in range(num_samples):
    if ex_label[i] == ex:
      temp_all_reps.append(dt_frame[i, :])
    else:
      pass # do nothing

  temp_all_reps = np.array(temp_all_reps)
  avg_dt_frame.append(np.mean(temp_all_reps, axis = 0))

avg_dt_frame = np.array(avg_dt_frame)

# %%
avg_dt_frame.shape
# Out:
# (37, 4400)

# %%
fig, ax = plt.subplots(figsize=(7,5), dpi=100)

ax.plot(avg_dt_frame[3])
ax.set_xlim([0, 2300])
# ax.set_ylim([-25, 20])

plt.show()

# %%
np.argwhere(np.isnan(avg_dt_frame))
# Out:
# array([], shape=(0, 2), dtype=int64)

# %% [markdown]
# Select the no. of clusters

# %%
from sklearn.cluster import KMeans
from sklearn import metrics

inertia = []
scaled_inertia = []
ch_id = []
silhouette = []

k = range(1, 20)

inertia_o = 0 # inertia when k = 1
alpha = 0.02

for num_clusters in k:
  kmeans = KMeans(n_clusters = num_clusters)
  kmeans.fit(avg_dt_frame)

  # Get inertia
  inertia.append(kmeans.inertia_)

  # Get scaled inertia
  if num_clusters == 1:
    inertia_o = kmeans.inertia_
  else:
    pass # do nothing

  scaled_inertia.append(kmeans.inertia_/inertia_o + alpha*num_clusters)

  # if num_clusters == 1:
  #   ch_id.append(0)
  #   silhouette.append(0)
  # else:
  #   # Get CH index
  #   labels = kmeans.labels_
  #   ch_id.append(metrics.calinski_harabasz_score(avg_dt_frame, labels))

  #   # Get Silhouette score
  #   silhouette.append(metrics.silhouette_score(avg_dt_frame, labels, metric='euclidean'))

# %%
# Plot inertia
plt.figure(figsize=(7,5), dpi=100)
plt.plot(k, inertia, 'bo-')
plt.xlabel('Value of k')
plt.ylabel('Inertia')
plt.title('Elbow method for optimal k')
plt.xlim([0,20])
plt.show()

# Plot scaled inertia
plt.figure(figsize=(7,5), dpi=100)
plt.plot(k, scaled_inertia, 'bo-')
plt.xlabel('Value of k')
plt.ylabel('Scaled inertia')
plt.title('Elbow method for optimal k')
plt.xlim([0,20])
plt.show()

# # Plot CH indes
# plt.figure(figsize=(7,5), dpi=100)
# plt.plot(k[1:], ch_id[1:], 'bo-')
# plt.xlabel('Value of k')
# plt.ylabel('CH index')
# plt.title('Elbow method for optimal k')
# plt.xlim([0,20])
# plt.show()

# # Plot CH indes
# plt.figure(figsize=(7,5), dpi=100)
# plt.plot(k[1:], silhouette[1:], 'bo-')
# plt.xlabel('Value of k')
# plt.ylabel('Silhouette')
# plt.title('Elbow method for optimal k')
# plt.xlim([0,20])
# plt.show()

# %% [markdown]
# Do clustering

# %%
from sklearn.cluster import KMeans
from sklearn import metrics

kmeans = KMeans(n_clusters=10, random_state=0).fit(avg_dt_frame)

# %%
# Form a distribution matrix
dist_mat = np.zeros([37, 10]) # init

for i in range(len(exercise_types)):
  row = int(i)
  col = int(kmeans.labels_[i])
  dist_mat[row, col] += 1

# %%
import seaborn as sns

dist_mat = pd.DataFrame(dist_mat, index = exercise_types)

plt.figure(figsize = (4, 10))
sns.heatmap(dist_mat, annot = True, cmap = 'Blues')
plt.title('RAW')
plt.xlabel('Cluster')
plt.ylabel('Exercise')
# Out:
# Text(20.722222222222214, 0.5, 'Exercise')

# %% [markdown]
# #The loop

# %% [markdown]
# Check device

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cpu device

# %% [markdown]
# The Great Loop *(including both hyper-parameters tuning and performance evaluation)*

# %%
# Removed subject 1 due to missing IMUs
all_subject_id = list(range(1, NUM_SUBJECT))

# Training/testing accuracy of performance evaluation
perf_train_acc = []
perf_test_acc = []

# Performance evaluation
for test_subject in all_subject_id[:]:
# for test_subject in all_subject_id:
  print('# Working on test subject ' + str(test_subject))

  # --- Divide training/testing data according to LOSOCV --- #
  train_list, test_list = [], []

  for sample in sample_list:    
    if sample[0, ID_SUBJECT_LABEL] != test_subject: # data not from the testing subject
      train_list.append(sample) 
    else: # data from the testing subject
      test_list.append(sample)

  ''' Hyper-parameters tuning loop with val_list '''
  # Get subject id from the train list
  train_subject_id = losocv_split_train_list(all_subject_id, test_subject)

  # Initialize the selected hyper-parameters
  s_batch_size = 0 
  s_num_out = 0
  s_kernel_size = 0
  s_stride = 0
  s_pool_size = 0

  hp_val_acc = 0

  # --- Loop throught the search space --- #
  print('--- Start the hyper-parameters searching')
  for hp_point in hp_search_space:

    t_bs = hp_point[ID_BATCH_SIZE]
    t_no = hp_point[ID_NUM_OUT]
    t_ks = hp_point[ID_KERNEL_SIZE]
    t_st = hp_point[ID_STRIDE] 
    t_ps = hp_point[ID_POOL_SIZE]

    temp_perf_val_acc = []

    for val_subject in train_subject_id:
      print('\t Val subject = ' + str(val_subject))

      # Divide training/val data according to LOSOCV
      temp_train_list, temp_val_list = [], []

      for sample in train_list:
        if sample[0, ID_SUBJECT_LABEL] != val_subject: # data not from the val subject
          temp_train_list.append(sample) 
        else: # data from the testing subject
          temp_val_list.append(sample)

      # Normalize data
      temp_train_data  = MyDataset(temp_train_list, NORM_SAMPLE_LENGTH)
      temp_test_data   = MyDataset(temp_val_list, NORM_SAMPLE_LENGTH)

      # Wrap dataloader   
      temp_train_dataloader  = DataLoader(temp_train_data, batch_size = t_bs, shuffle=True)
      temp_test_dataloader   = DataLoader(temp_test_data, batch_size  = t_bs, shuffle=False)

      # Model
      # temp_model = CNN_One_Block(conv_num_in, t_no, t_ks, t_st, t_ps)
      # temp_model = CNN_Two_Blocks(conv_num_in, t_no, t_ks, t_st, t_ps)
      # temp_model = CNN_Three_Blocks(conv_num_in, t_no, t_ks, t_st, t_ps)
      # temp_model = CNN_One_Deep_Block(conv_num_in, t_no, t_ks, t_st, t_ps)
      # temp_model = CNN_Two_Deep_Blocks(conv_num_in, t_no, t_ks, t_st, t_ps)
      # temp_model = CNN_Parallel_Blocks(conv_num_in, t_no, t_ks, t_st, t_ps)
      temp_model = CNN_Alter_Block(conv_num_in, t_no, t_ks, t_st, t_ps)
      # temp_model = CNN_Alter_Two_Block(conv_num_in, t_no, t_ks, t_st, t_ps)
      if device == 'cuda': temp_model = temp_model.cuda()

      # for plotting
      train_losses, val_losses = [], []

      # Initialize the loss function
      temp_loss_fn = nn.CrossEntropyLoss()

      # Initialize the optimisation function
      temp_optimizer = torch.optim.Adam(temp_model.parameters(), lr = LEARNING_RATE, weight_decay = ADAM_WEIGHT_DECAY)

      # Scheduler
      scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(temp_optimizer, 'min', factor = LEARNING_RATE_REDUCTION_FACTOR)

      for t in range(NUM_EPOCHS):
        # print(f"Epoch {t+1}\n-------------------------------")
        temp_train_acc  = train_loop(temp_train_dataloader, temp_model, temp_loss_fn, temp_optimizer)
        temp_val_acc   = test_loop(temp_test_dataloader, temp_model, temp_loss_fn)

      temp_perf_val_acc.append(temp_val_acc)

    # Update the hyper-parameters if getting better val accuracy
    temp_avg_val_acc = sum(temp_perf_val_acc)/len(train_subject_id)
    print('Temp. avg. val. acc. = ' + str(temp_avg_val_acc))

    if temp_avg_val_acc > hp_val_acc:
      # Update accuracy
      hp_val_acc = temp_avg_val_acc

      print('\t Parameters updated, and val_acc = ' + str(hp_val_acc))
      print('\t Parameters: ' + str(hp_point))

      # Update hyper-parameters
      s_batch_size = t_bs
      s_num_out = t_no
      s_kernel_size = t_ks
      s_stride = t_st
      s_pool_size = t_ps

    else:
      pass # do nothing

  print('--- Start the performance evaluation')
  # --- Make dataset --- #
  # Normalize
  train_data  = MyDataset(train_list, NORM_SAMPLE_LENGTH)
  test_data   = MyDataset(test_list, NORM_SAMPLE_LENGTH)

  # Wrap dataloader   
  train_dataloader  = DataLoader(train_data, batch_size = s_batch_size, shuffle=True)
  test_dataloader   = DataLoader(test_data, batch_size  = s_batch_size, shuffle=False)

  # --- Model and training --- #
  # Model
  # model = CNN_One_Block(conv_num_in, s_num_out, s_kernel_size, s_stride, s_pool_size)
  # model = CNN_Two_Blocks(conv_num_in, s_num_out, s_kernel_size, s_stride, s_pool_size)
  # model = CNN_Three_Blocks(conv_num_in, s_num_out, s_kernel_size, s_stride, s_pool_size)
  # model = CNN_One_Deep_Block(conv_num_in, s_num_out, s_kernel_size, s_stride, s_pool_size)
  # model = CNN_Two_Deep_Blocks(conv_num_in, s_num_out, s_kernel_size, s_stride, s_pool_size)
  # model = CNN_Parallel_Blocks(conv_num_in, s_num_out, s_kernel_size, s_stride, s_pool_size)
  model = CNN_Alter_Block(conv_num_in, s_num_out, s_kernel_size, s_stride, s_pool_size)
  # model = CNN_Alter_Two_Block(conv_num_in, s_num_out, s_kernel_size, s_stride, s_pool_size)
  if device == 'cuda': model = model.cuda()

  # for plotting
  train_losses, val_losses = [], []

  # Initialize the loss function
  loss_fn = nn.CrossEntropyLoss()

  # Initialize the optimisation function
  optimizer = torch.optim.Adam(model.parameters(), lr = LEARNING_RATE, weight_decay = ADAM_WEIGHT_DECAY)

  # Scheduler
  scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor = LEARNING_RATE_REDUCTION_FACTOR)

  for t in range(NUM_EPOCHS):
    print(f"Epoch {t+1}\n-------------------------------")
    temp_train_acc  = train_loop(train_dataloader, model, loss_fn, optimizer)
    temp_test_acc   = test_loop(test_dataloader, model, loss_fn)

  perf_train_acc.append(temp_train_acc)
  perf_test_acc.append(temp_test_acc)
  print(perf_train_acc)
  print(perf_test_acc)
# Out:
# # Working on test subject 1
# --- Start the hyper-parameters searching
# 	 Val subject = 2
# C:\Users\ngvup\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\lazy.py:178: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7178381020025222
# 	 Parameters updated, and val_acc = 0.7178381020025222
# 	 Parameters: [16, 32, 4, 1, 2]
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7448001002828606
# 	 Parameters updated, and val_acc = 0.7448001002828606
# 	 Parameters: [16, 64, 4, 1, 2]
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7582660408099561
# 	 Parameters updated, and val_acc = 0.7582660408099561
# 	 Parameters: [16, 128, 4, 1, 2]
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.752713186686276
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.732539958995646
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7580121935176956
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7692952763472893
# 	 Parameters updated, and val_acc = 0.7692952763472893
# 	 Parameters: [32, 128, 4, 1, 2]
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7711293874177182
# 	 Parameters updated, and val_acc = 0.7711293874177182
# 	 Parameters: [32, 256, 4, 1, 2]
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7183392525784222
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7442364235943838
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7599512703632305
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7732488983118515
# 	 Parameters updated, and val_acc = 0.7732488983118515
# 	 Parameters: [64, 256, 4, 1, 2]
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7183548653236538
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7469856041156782
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.757566761726059
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7690053421560241
# --- Start the performance evaluation
# Epoch 1
# -------------------------------
# Epoch 2
# -------------------------------
# Epoch 3
# -------------------------------
# Epoch 4
# -------------------------------
# Epoch 5
# -------------------------------
# Epoch 6
# -------------------------------
# Epoch 7
# -------------------------------
# Epoch 8
# -------------------------------
# Epoch 9
# -------------------------------
# Epoch 10
# -------------------------------
# Epoch 11
# -------------------------------
# Epoch 12
# -------------------------------
# Epoch 13
# -------------------------------
# Epoch 14
# -------------------------------
# Epoch 15
# -------------------------------
# Epoch 16
# -------------------------------
# Epoch 17
# -------------------------------
# Epoch 18
# -------------------------------
# Epoch 19
# -------------------------------
# Epoch 20
# -------------------------------
# Epoch 21
# -------------------------------
# Epoch 22
# -------------------------------
# Epoch 23
# -------------------------------
# Epoch 24
# -------------------------------
# Epoch 25
# -------------------------------
# Epoch 26
# -------------------------------
# Epoch 27
# -------------------------------
# Epoch 28
# -------------------------------
# Epoch 29
# -------------------------------
# Epoch 30
# -------------------------------
# [0.7868103166829905]
# [0.7905405405405406]
# # Working on test subject 2
# --- Start the hyper-parameters searching
# 	 Val subject = 1
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7177065595960787
# 	 Parameters updated, and val_acc = 0.7177065595960787
# 	 Parameters: [16, 32, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7516933799795198
# 	 Parameters updated, and val_acc = 0.7516933799795198
# 	 Parameters: [16, 64, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7561850958285171
# 	 Parameters updated, and val_acc = 0.7561850958285171
# 	 Parameters: [16, 128, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7669785181942217
# 	 Parameters updated, and val_acc = 0.7669785181942217
# 	 Parameters: [16, 256, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7237765605830943
# 	 Val subject = 1
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7607548614606814
# 	 Val subject = 1
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7660718369639352
# 	 Val subject = 1
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.765178592334747
# 	 Val subject = 1
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7182756466254063
# 	 Val subject = 1
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7419566869592177
# 	 Val subject = 1
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7664751526213714
# 	 Val subject = 1
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.782604643203079
# 	 Parameters updated, and val_acc = 0.782604643203079
# 	 Parameters: [64, 256, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.718826882991467
# 	 Val subject = 1
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7496748327764452
# 	 Val subject = 1
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7691271918098377
# 	 Val subject = 1
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7671859190933314
# --- Start the performance evaluation
# Epoch 1
# -------------------------------
# Epoch 2
# -------------------------------
# Epoch 3
# -------------------------------
# Epoch 4
# -------------------------------
# Epoch 5
# -------------------------------
# Epoch 6
# -------------------------------
# Epoch 7
# -------------------------------
# Epoch 8
# -------------------------------
# Epoch 9
# -------------------------------
# Epoch 10
# -------------------------------
# Epoch 11
# -------------------------------
# Epoch 12
# -------------------------------
# Epoch 13
# -------------------------------
# Epoch 14
# -------------------------------
# Epoch 15
# -------------------------------
# Epoch 16
# -------------------------------
# Epoch 17
# -------------------------------
# Epoch 18
# -------------------------------
# Epoch 19
# -------------------------------
# Epoch 20
# -------------------------------
# Epoch 21
# -------------------------------
# Epoch 22
# -------------------------------
# Epoch 23
# -------------------------------
# Epoch 24
# -------------------------------
# Epoch 25
# -------------------------------
# Epoch 26
# -------------------------------
# Epoch 27
# -------------------------------
# Epoch 28
# -------------------------------
# Epoch 29
# -------------------------------
# Epoch 30
# -------------------------------
# [0.7868103166829905, 0.8024286183130949]
# [0.7905405405405406, 0.7621951219512195]
# # Working on test subject 3
# --- Start the hyper-parameters searching
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7295200124396781
# 	 Parameters updated, and val_acc = 0.7295200124396781
# 	 Parameters: [16, 32, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.745897388204984
# 	 Parameters updated, and val_acc = 0.745897388204984
# 	 Parameters: [16, 64, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7731235798906378
# 	 Parameters updated, and val_acc = 0.7731235798906378
# 	 Parameters: [16, 128, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7724147944372861
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7368853732418736
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7574706134405268
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7701936879248121
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7771242853093262
# 	 Parameters updated, and val_acc = 0.7771242853093262
# 	 Parameters: [32, 256, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7213896034662896
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7447194727381675
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7583538444032317
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7657640880912503
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7013785134355578
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7499806065610787
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7609559766798637
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7729340159826075
# --- Start the performance evaluation
# Epoch 1
# -------------------------------
# Epoch 2
# -------------------------------
# Epoch 3
# -------------------------------
# Epoch 4
# -------------------------------
# Epoch 5
# -------------------------------
# Epoch 6
# -------------------------------
# Epoch 7
# -------------------------------
# Epoch 8
# -------------------------------
# Epoch 9
# -------------------------------
# Epoch 10
# -------------------------------
# Epoch 11
# -------------------------------
# Epoch 12
# -------------------------------
# Epoch 13
# -------------------------------
# Epoch 14
# -------------------------------
# Epoch 15
# -------------------------------
# Epoch 16
# -------------------------------
# Epoch 17
# -------------------------------
# Epoch 18
# -------------------------------
# Epoch 19
# -------------------------------
# Epoch 20
# -------------------------------
# Epoch 21
# -------------------------------
# Epoch 22
# -------------------------------
# Epoch 23
# -------------------------------
# Epoch 24
# -------------------------------
# Epoch 25
# -------------------------------
# Epoch 26
# -------------------------------
# Epoch 27
# -------------------------------
# Epoch 28
# -------------------------------
# Epoch 29
# -------------------------------
# Epoch 30
# -------------------------------
# [0.7868103166829905, 0.8024286183130949, 0.860236220472441]
# [0.7905405405405406, 0.7621951219512195, 0.8282208588957055]
# # Working on test subject 4
# --- Start the hyper-parameters searching
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7318277451594309
# 	 Parameters updated, and val_acc = 0.7318277451594309
# 	 Parameters: [16, 32, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7500303684723595
# 	 Parameters updated, and val_acc = 0.7500303684723595
# 	 Parameters: [16, 64, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.76351475439661
# 	 Parameters updated, and val_acc = 0.76351475439661
# 	 Parameters: [16, 128, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7642238951963464
# 	 Parameters updated, and val_acc = 0.7642238951963464
# 	 Parameters: [16, 256, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.724608982042181
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7518138337499485
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7612000710429012
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7682286232895359
# 	 Parameters updated, and val_acc = 0.7682286232895359
# 	 Parameters: [32, 256, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7305266905765025
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7422140876959615
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7664495746497321
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7696203114801707
# 	 Parameters updated, and val_acc = 0.7696203114801707
# 	 Parameters: [64, 256, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7009143971611013
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7486148802896516
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7629854900563249
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.770329264951141
# 	 Parameters updated, and val_acc = 0.770329264951141
# 	 Parameters: [128, 256, 4, 1, 2]
# --- Start the performance evaluation
# Epoch 1
# -------------------------------
# Epoch 2
# -------------------------------
# Epoch 3
# -------------------------------
# Epoch 4
# -------------------------------
# Epoch 5
# -------------------------------
# Epoch 6
# -------------------------------
# Epoch 7
# -------------------------------
# Epoch 8
# -------------------------------
# Epoch 9
# -------------------------------
# Epoch 10
# -------------------------------
# Epoch 11
# -------------------------------
# Epoch 12
# -------------------------------
# Epoch 13
# -------------------------------
# Epoch 14
# -------------------------------
# Epoch 15
# -------------------------------
# Epoch 16
# -------------------------------
# Epoch 17
# -------------------------------
# Epoch 18
# -------------------------------
# Epoch 19
# -------------------------------
# Epoch 20
# -------------------------------
# Epoch 21
# -------------------------------
# Epoch 22
# -------------------------------
# Epoch 23
# -------------------------------
# Epoch 24
# -------------------------------
# Epoch 25
# -------------------------------
# Epoch 26
# -------------------------------
# Epoch 27
# -------------------------------
# Epoch 28
# -------------------------------
# Epoch 29
# -------------------------------
# Epoch 30
# -------------------------------
# [0.7868103166829905, 0.8024286183130949, 0.860236220472441, 0.8238375900458416]
# [0.7905405405405406, 0.7621951219512195, 0.8282208588957055, 0.7834394904458599]
# # Working on test subject 5
# --- Start the hyper-parameters searching
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7150908529441167
# 	 Parameters updated, and val_acc = 0.7150908529441167
# 	 Parameters: [16, 32, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.745030127921922
# 	 Parameters updated, and val_acc = 0.745030127921922
# 	 Parameters: [16, 64, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7555754167438125
# 	 Parameters updated, and val_acc = 0.7555754167438125
# 	 Parameters: [16, 128, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7689114111858232
# 	 Parameters updated, and val_acc = 0.7689114111858232
# 	 Parameters: [16, 256, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7309993561157032
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7471998149633264
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7674424699493881
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7613547403395052
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7187228106881145
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7440239749950079
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7518786038903397
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7693268323821303
# 	 Parameters updated, and val_acc = 0.7693268323821303
# 	 Parameters: [64, 256, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.715353151433238
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7408976829480092
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.755097550206359
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7594740221776904
# --- Start the performance evaluation
# Epoch 1
# -------------------------------
# Epoch 2
# -------------------------------
# Epoch 3
# -------------------------------
# Epoch 4
# -------------------------------
# Epoch 5
# -------------------------------
# Epoch 6
# -------------------------------
# Epoch 7
# -------------------------------
# Epoch 8
# -------------------------------
# Epoch 9
# -------------------------------
# Epoch 10
# -------------------------------
# Epoch 11
# -------------------------------
# Epoch 12
# -------------------------------
# Epoch 13
# -------------------------------
# Epoch 14
# -------------------------------
# Epoch 15
# -------------------------------
# Epoch 16
# -------------------------------
# Epoch 17
# -------------------------------
# Epoch 18
# -------------------------------
# Epoch 19
# -------------------------------
# Epoch 20
# -------------------------------
# Epoch 21
# -------------------------------
# Epoch 22
# -------------------------------
# Epoch 23
# -------------------------------
# Epoch 24
# -------------------------------
# Epoch 25
# -------------------------------
# Epoch 26
# -------------------------------
# Epoch 27
# -------------------------------
# Epoch 28
# -------------------------------
# Epoch 29
# -------------------------------
# Epoch 30
# -------------------------------
# [0.7868103166829905, 0.8024286183130949, 0.860236220472441, 0.8238375900458416, 0.8131976362442548]
# [0.7905405405405406, 0.7621951219512195, 0.8282208588957055, 0.7834394904458599, 0.7878787878787878]
# # Working on test subject 6
# --- Start the hyper-parameters searching
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7305392003543772
# 	 Parameters updated, and val_acc = 0.7305392003543772
# 	 Parameters: [16, 32, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7608914839212702
# 	 Parameters updated, and val_acc = 0.7608914839212702
# 	 Parameters: [16, 64, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7691132562956816
# 	 Parameters updated, and val_acc = 0.7691132562956816
# 	 Parameters: [16, 128, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.772305415693894
# 	 Parameters updated, and val_acc = 0.772305415693894
# 	 Parameters: [16, 256, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7210362821643117
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7506433180772379
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7706783943586557
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7747209215779423
# 	 Parameters updated, and val_acc = 0.7747209215779423
# 	 Parameters: [32, 256, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7233198603970352
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7599115994167982
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7677217459236266
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7775034019963131
# 	 Parameters updated, and val_acc = 0.7775034019963131
# 	 Parameters: [64, 256, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7146097279263318
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7354097828843503
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7732840739958823
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7660659303464081
# --- Start the performance evaluation
# Epoch 1
# -------------------------------
# Epoch 2
# -------------------------------
# Epoch 3
# -------------------------------
# Epoch 4
# -------------------------------
# Epoch 5
# -------------------------------
# Epoch 6
# -------------------------------
# Epoch 7
# -------------------------------
# Epoch 8
# -------------------------------
# Epoch 9
# -------------------------------
# Epoch 10
# -------------------------------
# Epoch 11
# -------------------------------
# Epoch 12
# -------------------------------
# Epoch 13
# -------------------------------
# Epoch 14
# -------------------------------
# Epoch 15
# -------------------------------
# Epoch 16
# -------------------------------
# Epoch 17
# -------------------------------
# Epoch 18
# -------------------------------
# Epoch 19
# -------------------------------
# Epoch 20
# -------------------------------
# Epoch 21
# -------------------------------
# Epoch 22
# -------------------------------
# Epoch 23
# -------------------------------
# Epoch 24
# -------------------------------
# Epoch 25
# -------------------------------
# Epoch 26
# -------------------------------
# Epoch 27
# -------------------------------
# Epoch 28
# -------------------------------
# Epoch 29
# -------------------------------
# Epoch 30
# -------------------------------
# [0.7868103166829905, 0.8024286183130949, 0.860236220472441, 0.8238375900458416, 0.8131976362442548, 0.8101806239737275]
# ...
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.6999089283998351
# 	 Parameters updated, and val_acc = 0.6999089283998351
# 	 Parameters: [16, 32, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7503113504780002
# 	 Parameters updated, and val_acc = 0.7503113504780002
# 	 Parameters: [16, 64, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7628475331812878
# 	 Parameters updated, and val_acc = 0.7628475331812878
# 	 Parameters: [16, 128, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.758632886882795
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7257610619305987
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7523952871325602
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7672023452245899
# 	 Parameters updated, and val_acc = 0.7672023452245899
# 	 Parameters: [32, 128, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7591492097348772
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7204192509648859
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7360322427711492
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7528283758525778
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7712665636814134
# 	 Parameters updated, and val_acc = 0.7712665636814134
# 	 Parameters: [64, 256, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7236675730903794
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7386051968555093
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.755433785808802
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 12
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7735229878453479
# 	 Parameters updated, and val_acc = 0.7735229878453479
# 	 Parameters: [128, 256, 4, 1, 2]
# --- Start the performance evaluation
# Epoch 1
# -------------------------------
# Epoch 2
# -------------------------------
# Epoch 3
# -------------------------------
# Epoch 4
# -------------------------------
# Epoch 5
# -------------------------------
# Epoch 6
# -------------------------------
# Epoch 7
# -------------------------------
# Epoch 8
# -------------------------------
# Epoch 9
# -------------------------------
# Epoch 10
# -------------------------------
# Epoch 11
# -------------------------------
# Epoch 12
# -------------------------------
# Epoch 13
# -------------------------------
# Epoch 14
# -------------------------------
# Epoch 15
# -------------------------------
# Epoch 16
# -------------------------------
# Epoch 17
# -------------------------------
# Epoch 18
# -------------------------------
# Epoch 19
# -------------------------------
# Epoch 20
# -------------------------------
# Epoch 21
# -------------------------------
# Epoch 22
# -------------------------------
# Epoch 23
# -------------------------------
# Epoch 24
# -------------------------------
# Epoch 25
# -------------------------------
# Epoch 26
# -------------------------------
# Epoch 27
# -------------------------------
# Epoch 28
# -------------------------------
# Epoch 29
# -------------------------------
# Epoch 30
# -------------------------------
# [0.7868103166829905, 0.8024286183130949, 0.860236220472441, 0.8238375900458416, 0.8131976362442548, 0.8101806239737275, 0.796844181459566, 0.8779050736497545, 0.8105986261040236, 0.8068965517241379, 0.8656178302196001]
# [0.7905405405405406, 0.7621951219512195, 0.8282208588957055, 0.7834394904458599, 0.7878787878787878, 0.7228915662650602, 0.7455621301775148, 0.7435897435897436, 0.8051948051948052, 0.7650602409638554, 0.85]
# # Working on test subject 12
# --- Start the hyper-parameters searching
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7211309044189108
# 	 Parameters updated, and val_acc = 0.7211309044189108
# 	 Parameters: [16, 32, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.748744562799732
# 	 Parameters updated, and val_acc = 0.748744562799732
# 	 Parameters: [16, 64, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7685160929425152
# 	 Parameters updated, and val_acc = 0.7685160929425152
# 	 Parameters: [16, 128, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7723266571240288
# 	 Parameters updated, and val_acc = 0.7723266571240288
# 	 Parameters: [16, 256, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7271304857435579
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7471148436019782
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7739897617044291
# 	 Parameters updated, and val_acc = 0.7739897617044291
# 	 Parameters: [32, 128, 4, 1, 2]
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7672882510945493
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# 	 Val subject = 19
# Temp. avg. val. acc. = 0.7381067211632817
# 	 Val subject = 1
# 	 Val subject = 2
# 	 Val subject = 3
# 	 Val subject = 4
# 	 Val subject = 5
# 	 Val subject = 6
# 	 Val subject = 7
# 	 Val subject = 8
# 	 Val subject = 9
# 	 Val subject = 10
# 	 Val subject = 11
# 	 Val subject = 13
# 	 Val subject = 14
# 	 Val subject = 15
# 	 Val subject = 16
# 	 Val subject = 17
# 	 Val subject = 18
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [173], line 92
#      88 scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(temp_optimizer, 'min', factor = LEARNING_RATE_REDUCTION_FACTOR)
#      90 for t in range(NUM_EPOCHS):
#      91   # print(f"Epoch {t+1}\n-------------------------------")
# ---> 92   temp_train_acc  = train_loop(temp_train_dataloader, temp_model, temp_loss_fn, temp_optimizer)
#      93   temp_val_acc   = test_loop(temp_test_dataloader, temp_model, temp_loss_fn)
#      95 temp_perf_val_acc.append(temp_val_acc)
#
# Cell In [140], line 27, in train_loop(dataloader, model, loss_fn, optimizer)
#      25 optimizer.zero_grad()
#      26 loss.backward()
# ---> 27 optimizer.step()
#      29 if batch % 20 == 0:
#      30     loss, current = loss.item(), batch * len(X)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\optim\optimizer.py:113, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     111 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     112 with torch.autograd.profiler.record_function(profile_name):
# --> 113     return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\autograd\grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\optim\adam.py:157, in Adam.step(self, closure)
#     153                 max_exp_avg_sqs.append(state['max_exp_avg_sq'])
#     155             state_steps.append(state['step'])
# --> 157     adam(params_with_grad,
#     158          grads,
#     159          exp_avgs,
#     160          exp_avg_sqs,
#     161          max_exp_avg_sqs,
#     162          state_steps,
#     163          amsgrad=group['amsgrad'],
#     164          beta1=beta1,
#     165          beta2=beta2,
#     166          lr=group['lr'],
#     167          weight_decay=group['weight_decay'],
#     168          eps=group['eps'],
#     169          maximize=group['maximize'],
#     170          foreach=group['foreach'],
#     171          capturable=group['capturable'])
#     173 return loss
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\optim\adam.py:213, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     210 else:
#     211     func = _single_tensor_adam
# --> 213 func(params,
#     214      grads,
#     215      exp_avgs,
#     216      exp_avg_sqs,
#     217      max_exp_avg_sqs,
#     218      state_steps,
#     219      amsgrad=amsgrad,
#     220      beta1=beta1,
#     221      beta2=beta2,
#     222      lr=lr,
#     223      weight_decay=weight_decay,
#     224      eps=eps,
#     225      maximize=maximize,
#     226      capturable=capturable)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\optim\adam.py:263, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable)
#     261 # Decay the first and second moment running average coefficient
#     262 exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
# --> 263 exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     265 if capturable:
#     266     step = step_t
#
# KeyboardInterrupt:
